# %% [markdown]
# # CrisisWorld — GRPO with Hugging Face TRL (Colab)
#
# Minimal flow: clone repo → install training deps → run `train_grpo.py` with GPU.
#
# **Replace** `YOUR_GITHUB_REPO_URL` with your public fork before the hackathon.

# %%
# Optional: HF token for model download rate limits
# import os; os.environ["HF_TOKEN"] = "hf_xxx"

# !git clone YOUR_GITHUB_REPO_URL crisisworld
# %cd crisisworld/backend
# !pip install -q -r requirements.txt -r requirements-train.txt

# %%
# Short smoke run (increase max steps for real submission)
# !python train_grpo.py

# %%
# Plot artifacts (after training writes checkpoints/crisisworld-grpo/)
# !python scripts/plot_training_run.py --checkpoint-dir checkpoints/crisisworld-grpo --out-dir ../docs/training_plots
from IPython.display import Image, display
display(Image("../docs/training_plots/reward_vs_episode.png"))
